# %%
# %%markdown
# ## Assignment2
# ### -- Yuanjie Yue
# Out:
# ## Assignment2
# ### -- Yuanjie Yue

# %%
# preparation
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# load the iris data.
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data" 
df = pd.read_csv(url, header=None, names=["Sepal Length", "Sepal Width","Petal Length", "Petal Width", "Name"])

# %%
# %%markdown
# ## 1.1 Summary Statistics
# Out:
# ## 1.1 Summary Statistics

# %%
# 1. Print the ﬁrst 5 elements of your DataFrame
df.head()
# Out:
#    Sepal Length  Sepal Width  Petal Length  Petal Width         Name
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df['Sepal Length'].dtype
# Out:
# dtype('float64')

# %%
# %%markdown
# #### How many features are there and what are their types ?
# There are four features, namely 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'.
#
# All of them are of numeric types, more specifically, float64.
# Out:
# #### How many features are there and what are their types ?
# There are four features, namely 'Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width'.
#
# All of them are of numeric types, more specifically, float64.

# %%
# 2. Compute and display summary statistics for each numeric feature
df.describe()
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# %%markdown
# ## 1.2 Data Visualization
# Out:
# ## 1.2 Data Visualization

# %%
# 1. Visualize with Histogram
df.hist(figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11ba00a10>,
# ...
#       dtype=object)

# %%
plt.hist(df['Sepal Length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['Sepal Width'])
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['Petal Length'])
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['Petal Width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <a list of 10 Patch objects>)

# %%
# 2. Visualize Box Plot
# One way is using boxplot method of data frame.
df.boxplot(grid=False)

# %%
# the other way is doing by leveraging matplotlib pyplot.
fig = plt.figure()
ax = fig.add_subplot(111)

x1 = df['Sepal Length']
x2 = df['Sepal Width']
x3 = df['Petal Length']
x4 = df['Petal Width']

df_boxplot = ax.boxplot([x1,x2,x3,x4])

# %%
# %%markdown
# ## 2.1 Imputation
# Out:
# ## 2.1 Imputation

# %%
# load the housing data.
pd.set_option("display.max_columns", 100) 
url = "https://raw.githubusercontent.com/cs6220/cs6220.spring2019/master/data/AmesHousing.txt" 
df = pd.read_csv(url, sep="\t")

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
# get the class of the data.
df_class=df.iloc[:, -1]

# %%
df_class.head()
# Out:
# 0    215000
# 1    105000
# 2    172000
# 3    244000
# 4    189900
# Name: SalePrice, dtype: int64

# %%
# get all the features of the data.
df=df.iloc[:, :-1]

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
# 1. How many features have missing values?
null_value_nums = df.isnull().sum()
num_of_feature_have_missing_values = null_value_nums[null_value_nums > 0].count()

# %%
print('there are {} features have missing values in the dataset!'.format(num_of_feature_have_missing_values))
# Out:
# there are 27 features have missing values in the dataset!

# %%
# 2. Fill each missing nominal feature value with the string “Missing”
for col in df.columns:
    # check if the current column is not 'boolean', 'int', 'usigned int', 'float', 'complex'.
    if not np.issubdtype(df[col].dtype, np.number):
        df[col] = df[col].fillna('Missing')

# %%
nominal_feature_missing_values_nums = df.select_dtypes(exclude=['int','float']).isnull().sum()

# %%
nominal_missing_num = nominal_feature_missing_values_nums[nominal_feature_missing_values_nums > 0].count()

# %%
print('nominal features that have missing values are {}.'.format(nominal_missing_num))
# Out:
# nominal features that have missing values are 0.

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0  Missing       IR1          Lvl    AllPub     Corner        Gtl
# 1  Missing       Reg          Lvl    AllPub     Inside        Gtl
# 2  Missing       IR1          Lvl    AllPub     Corner        Gtl
# 3  Missing       Reg          Lvl    AllPub     Corner        Gtl
# 4  Missing       IR1          Lvl    AllPub     Inside        Gtl
#
#   Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# ...

# %%
# 3. Interpolate each missing numeric feature value using linear interpolation.
df = df.interpolate()

# %%
numeric_feature_missing_values_nums = df.select_dtypes(include=['int','float']).isnull().sum()

# %%
numeric_missing_num = numeric_feature_missing_values_nums[numeric_feature_missing_values_nums > 0].count()

# %%
print('numeric features that have missing values are {}.'.format(numeric_missing_num))
# Out:
# numeric features that have missing values are 0.

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0  Missing       IR1          Lvl    AllPub     Corner        Gtl
# 1  Missing       Reg          Lvl    AllPub     Inside        Gtl
# 2  Missing       IR1          Lvl    AllPub     Corner        Gtl
# 3  Missing       Reg          Lvl    AllPub     Corner        Gtl
# 4  Missing       IR1          Lvl    AllPub     Inside        Gtl
#
#   Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# ...

# %%
# %%markdown
# ## 2.2 Standardization
# Out:
# ## 2.2 Standardization

# %%
# pick up all the numeric features
df = df.select_dtypes(include=['int','float'])

# %%
# prop irrelavant columns.
df.drop(columns=['Order','PID'],inplace=True)

# %%
from sklearn import preprocessing as pp

# %%
df.boxplot(grid=False,figsize=(48,12))

# %%
# 1. Standardize the imputed feature data so that the values of each numeric feature are standard normally distributed
for col in df:
    df[col] = pp.scale(df[col], axis=0, with_mean=True, with_std=True, copy=True)

# %%
# 2. Visualize the results using box plots.
df.boxplot(grid=False,figsize=(48,12))

# %%
# %%markdown
# * __How do the plots diﬀer from box plots made before feature standardization?__
#
# We can not see to much details of the data before standradization, becasue some of the value of the 'Lot Area' feature
# is so large that it blocked the other features.
#
# However, all of the features are of similar value scope, which make it easier to see through the data.
#
# Besides, All of the features have been standardized, all of them have the mean of 0 and std of 1.
#
# * __Which feature has the outlier furthest from the mean before and after standardization?__
#
# The feature 'Lot Area' has the outlier furthest from the mean before the standradization and 'Misc Val' after standardization.
# Out:
# * __How do the plots diﬀer from box plots made before feature standardization?__
#
# We can not see to much details of the data before standradization, becasue some of the value of the 'Lot Area' feature
# is so large that it blocked the other features.
#
# However, all of the features are of similar value scope, which make it easier to see through the data.
#
# Besides, All of the features have been standardized, all of them have the mean of 0 and std of 1.
#
# * __Which feature has the outlier furthest from the mean before and after standardization?__
#
# The feature 'Lot Area' has the outlier furthest from the mean before the standradization and 'Misc Val' after standardization.

# %%
# %%markdown
# ## 2.3 Feature Selection
# Out:
# ## 2.3 Feature Selection

# %%
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest

# %%
X=df
y=df_class

# %%
# 1. To get an idea of their relative importance, estimate the mutual information between 
# the numeric features and the class column, ‘SalePrice’
mi = mutual_info_classif(X, y)

# %%
mi
# Out:
# array([0.36066701, 0.16909647, 0.11742297, 0.77094129, 0.75432793,
#        0.35521574, 0.32895342, 0.88317356, 0.24228368, 1.65793639,
#        0.06067495, 0.29019005, 0.25787948, 0.56630826, 2.03348666,
#        0.44165739, 0.92770763, 2.18112427, 1.5059505 , 1.08292922,
#        0.57130911, 2.00018498, 0.45233154, 1.06733412, 0.26774724,
#        1.23249718, 0.36405724, 0.53900842, 0.51625155, 1.50426631,
#        1.97130095, 1.72772279, 2.25095203, 1.96444077, 0.0544791 ,
#        0.25340689])

# %%
mi_infos=pd.DataFrame(mi)

# %%
# rename the column as score
mi_infos.rename(columns={0: 'score'},inplace=True)

# %%
# add the original feature name as a new column.
mi_infos['feature'] = pd.DataFrame(X.columns)

# %%
# sort the new dataframe by score in descending order.
mi_infos.sort_values(by='score',ascending=False)
# Out:
#        score          feature
# 32  2.250952        Pool Area
# 17  2.181124   Bsmt Half Bath
# 14  2.033487  Low Qual Fin SF
# 21  2.000185    Kitchen AbvGr
# 30  1.971301       3Ssn Porch
# 33  1.964441         Misc Val
# 31  1.727723     Screen Porch
# 9   1.657936     BsmtFin SF 2
# 18  1.505950        Full Bath
# 29  1.504266   Enclosed Porch
# 25  1.232497      Garage Cars
# 19  1.082929        Half Bath
# 23  1.067334       Fireplaces
# 16  0.927708   Bsmt Full Bath
# 7   0.883174     Mas Vnr Area
# 3   0.770941     Overall Qual
# 4   0.754328     Overall Cond
# 20  0.571309    Bedroom AbvGr
# 13  0.566308       2nd Flr SF
# 27  0.539008     Wood Deck SF
# 28  0.516252    Open Porch SF
# 22  0.452332    TotRms AbvGrd
# 15  0.441657      Gr Liv Area
# 26  0.364057      Garage Area
# 0   0.360667      MS SubClass
# 5   0.355216       Year Built
# 6   0.328953   Year Remod/Add
# 11  0.290190    Total Bsmt SF
# 24  0.267747    Garage Yr Blt
# 12  0.257879       1st Flr SF
# ...

# %%
# 2. What are the top 5 numeric features ranked by mutual information?

# %%
# Select the k best features.
selector = SelectKBest(mutual_info_classif, k=5)
selector.fit(X, y)

# Get indices of columns to keep.
idxs_selected = selector.get_support(indices=True)

# Create new DataFrame with only desired columns.
X_new = X.iloc[:, idxs_selected]

# Show the top 5 features.
X_new.head()
# Out:
#    Low Qual Fin SF  Bsmt Half Bath  Kitchen AbvGr  3Ssn Porch  Pool Area
# 0        -0.101005       -0.249782      -0.207291   -0.103134  -0.063031
# 1        -0.101005       -0.249782      -0.207291   -0.103134  -0.063031
# 2        -0.101005       -0.249782      -0.207291   -0.103134  -0.063031
# 3        -0.101005       -0.249782      -0.207291   -0.103134  -0.063031
# 4        -0.101005       -0.249782      -0.207291   -0.103134  -0.063031

# %%
print('Top 5 features that affect the Sales Price most are: ')
for x in X_new.columns:
    print('    ' + x)
# Out:
# Top 5 features that affect the Sales Price most are:
#     Low Qual Fin SF
#     Bsmt Half Bath
#     Kitchen AbvGr
#     3Ssn Porch
#     Pool Area

# %%
# 3. How do you expect the values for the top-ranked feature to aﬀect the sales price 
# (i.e., would you expect the sales price to increase when its values go up or down)? Why?

# %%
# %%markdown
# I'll expect as follows:
# * for 'Low Qual Fin SF', the sales price will increase when its values go down.
# * for 'Kitchen AbvGr', the sales price will increase when its values go up.
# * for '3Ssn Porch', the sales price will increase when its values go up.
# * for 'Pool Area', the sales price will increase when its values go down.
# * for 'Misc Val', the salse price will increase when its values go up.
# Out:
# I'll expect as follows:
# * for 'Low Qual Fin SF', the sales price will increase when its values go down.
# * for 'Kitchen AbvGr', the sales price will increase when its values go up.
# * for '3Ssn Porch', the sales price will increase when its values go up.
# * for 'Pool Area', the sales price will increase when its values go down.
# * for 'Misc Val', the salse price will increase when its values go up.
